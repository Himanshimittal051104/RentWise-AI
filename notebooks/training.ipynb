# %%
import pandas as pd

# %%
df=pd.read_csv("house_data.csv")
print(df.columns)
df.head()
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')
#     Posted On  BHK   Rent  ...  Tenant Preferred Bathroom Point of Contact
# 0  2022-05-18    2  10000  ...  Bachelors/Family        2    Contact Owner
# 1  2022-05-13    2  20000  ...  Bachelors/Family        1    Contact Owner
# 2  2022-05-16    2  17000  ...  Bachelors/Family        1    Contact Owner
# 3  2022-07-04    2  10000  ...  Bachelors/Family        1    Contact Owner
# 4  2022-05-09    2   7500  ...         Bachelors        1    Contact Owner
#
# [5 rows x 12 columns]

# %%
df=df.rename(columns={
    "City":"city",
    "Area Locality":"area_locality",
    "Size":"size",
    "BHK":"bhk",
    "Bathroom":"bathroom",
    "Rent":"rent"
})
df.columns
# Out:
# Index(['Posted On', 'bhk', 'rent', 'size', 'Floor', 'Area Type',
#        'area_locality', 'city', 'Furnishing Status', 'Tenant Preferred',
#        'bathroom', 'Point of Contact'],
#       dtype='object')

# %%
df=df[["city","rent","bhk","bathroom","area_locality","size"]]
df.head()
# Out:
#       city   rent  bhk  bathroom             area_locality  size
# 0  Kolkata  10000    2         2                    Bandel  1100
# 1  Kolkata  20000    2         1  Phool Bagan, Kankurgachi   800
# 2  Kolkata  17000    2         1   Salt Lake City Sector 2  1000
# 3  Kolkata  10000    2         1               Dumdum Park   800
# 4  Kolkata   7500    2         1             South Dum Dum   850

# %%
df=pd.get_dummies(df,columns=['city','area_locality'])
df.head()
# Out:
#     rent  ...  area_locality_whitefield
# 0  10000  ...                     False
# 1  20000  ...                     False
# 2  17000  ...                     False
# 3  10000  ...                     False
# 4   7500  ...                     False
#
# [5 rows x 2245 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import joblib

y=df["rent"]
x=df.drop("rent",axis=1)

print("x shape", x.shape)
print("y shape", y.shape)
# Out:
# x shape (4746, 2244)
# y shape (4746,)

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,y, test_size=0.2, random_state=42
)

model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)

# %%
import numpy as np
rmse=np.sqrt(mean_squared_error(y_test, pred))
print("RMSE:", rmse)
# Out:
# RMSE: 64814.35833080548

# %%
joblib.dump(model, "../backend/model/house_model.pkl")
joblib.dump(x.columns.tolist(),"../backend/model/columns.pkl")
print("Model saved!")
# Out:
# Model saved!
